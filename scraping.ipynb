# %% [markdown]
# Scraping

# %%
import requests
from bs4 import BeautifulSoup as bs
import csv
import re
import pandas as pd

# %% [markdown]
# Take data from requests and write it in csv format

# %%
def data_to_csv(data):
    keys = data[0].keys()
    with open('data.csv', 'w', newline='')  as output_file:
        dict_writer = csv.DictWriter(output_file, keys)
        dict_writer.writeheader()
        dict_writer.writerows(data)

# %% [markdown]
# Function that format text elimninating \n \r \t character

# %%
def format_text(text):
    regex = re.compile(r'[\n\r\t]')
    text = regex.sub('', text)

    return " ".join(text.split())

# %% [markdown]
# Function that format currency, eliminating euro symbol, milion and dot

# %%
def format_currency(value):
    value = value.replace('€', '')
    value = value.replace('Loan fee:', '')
    
    if value[-1] == 'm':
        value = value.replace('m', '')
        return int(float(value)) * 1000000

    if value[-1] == '.':
        value = value.replace('.', '')
        if value[-2:] == 'Th':
            value = value.replace('Th', '')
            return int(value) * 1000
    
    return value

# %% [markdown]
# Function that given header and url access the webpage. It makes the request and then use beautiful soup to parse it. Then acess the right element (from responsive table to tbody), and store the information into a dataframe. The input is the namber of pages to be parsed

# %%
def get_data(pages):
    players_list = []
    for page in range(1, pages+1):
        headers = {"User-Agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36"}

        url  = f'https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page={page}&plus=1&saison-id=2020&spielerposition_id=&transferfenster='

        print(url)

        html = requests.get(url, headers=headers)
        soup = bs(html.content)

        soup = soup.select('.responsive-table > .grid-view > .items > tbody')[0]

        try:
            for cells in soup.find_all(True, {"class": re.compile("^(even|odd)$")}):
                fee = cells.find_all('td')[16].text
                position = cells.find_all('td')[4].text
                age = cells.find_all('td')[5].text
                market_value = cells.find_all('td')[6].text
                country_from = cells.find_all('td')[11].img['title']
                league_from = cells.find_all('td')[11].a.text if cells.find_all('td')[11].a != None else 'Without League'
                club_from = cells.find_all('td')[9].img['alt']
                country_to = cells.find_all('td')[15].img['alt']
                league_to = cells.find_all('td')[15].a.text if cells.find_all('td')[15].a != None else 'Without League'
                club_to = cells.find_all('td')[13].img['alt']

                player = {
                    'name': cells.find_all('td')[1].select('td > img')[0]['title'],
                    'position': position,
                    'age': age,
                    'market_value': format_currency(market_value),
                    'country_from': country_from,
                    'league_from': format_text(league_from),
                    'club_from': club_from,
                    'country_to': country_to,
                    'league_to': format_text(league_to),
                    'club_to': club_to,
                    'fee': format_currency(fee),
                }

                players_list.append(player)
        except IndexError:
            pass

    return players_list

# %%
data = get_data(100)
df = pd.DataFrame(data)

df.to_csv('transfer_window.csv')
# Out:
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=1&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=2&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=3&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=4&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=5&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=6&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=7&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=8&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=9&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=10&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=11&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=12&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=13&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=14&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=15&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=16&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=17&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=18&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=19&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=20&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=21&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=22&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=23&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=24&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=25&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=26&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=27&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=28&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=29&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=30&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=31&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=32&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=33&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=34&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=35&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=36&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=37&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=38&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=39&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=40&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=41&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=42&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=43&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=44&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=45&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=46&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=47&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=48&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=49&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=50&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=51&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=52&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=53&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=54&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=55&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=56&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=57&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=58&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=59&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=60&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=61&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=62&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=63&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=64&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=65&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=66&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=67&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=68&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=69&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=70&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=71&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=72&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=73&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=74&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=75&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=76&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=77&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=78&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=79&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=80&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=81&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=82&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=83&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=84&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=85&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=86&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=87&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=88&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=89&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=90&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=91&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=92&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=93&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=94&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=95&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=96&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=97&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=98&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=99&plus=1&saison-id=2020&spielerposition_id=&transferfenster=
# https://www.transfermarkt.com/transfers/saisontransfers/statistik?ajax=yw0&altersklasse=&ausrichtung=&land_id=0&leihe=&page=100&plus=1&saison-id=2020&spielerposition_id=&transferfenster=

# %%
df
# Out:
#                      name            position age market_value country_from  \
# 0          Erling Haaland      Centre-Forward  21    150000000      Germany
# 1          Enzo Fernández    Central Midfield  22     55000000     Portugal
# 2                  Antony        Right Winger  22     35000000  Netherlands
# 3           Wesley Fofana         Centre-Back  21     40000000      England
# 4     Aurélien Tchouaméni  Defensive Midfield  22     60000000       Monaco
# ...                   ...                 ...  ..          ...          ...
# 2495        Pep Chavarría           Left-Back  24         800k        Spain
# 2496               Nonato  Attacking Midfield  24      1000000       Brazil
# 2497     Frantzdy Pierrot      Centre-Forward  27      1000000       France
# 2498           Caio Vidal        Right Winger  22      1000000       Brazil
# 2499        Augusto Lotti      Second Striker  26      1000000    Argentina
#
#             league_from                 club_from country_to  \
# 0            Bundesliga         Borussia Dortmund    England
# 1         Liga Portugal                SL Benfica    England
# 2            Eredivisie            Ajax Amsterdam    England
# 3        Premier League            Leicester City    England
# 4               Ligue 1                 AS Monaco      Spain
# ...                 ...                       ...        ...
# 2495            LaLiga2             Real Zaragoza      Spain
# 2496            Série A  Sport Club Internacional   Bulgaria
# 2497            Ligue 2               EA Guingamp     Israel
# 2498  Campeonato Gaúcho  Sport Club Internacional   Bulgaria
# 2499   Liga Profesional     Club Atlético Tucumán     Mexico
#
#              league_to             club_to        fee
# 0       Premier League     Manchester City   60000000
# 1       Premier League          Chelsea FC  121000000
# 2       Premier League   Manchester United   95000000
# 3       Premier League          Chelsea FC   80000000
# 4               LaLiga         Real Madrid   80000000
# ...                ...                 ...        ...
# 2495            LaLiga      Rayo Vallecano    1000000
# 2496        efbet Liga  Ludogorets Razgrad    1000000
# 2497       Ligat ha'Al       Maccabi Haifa    1000000
# 2498        efbet Liga  Ludogorets Razgrad    1000000
# 2499  Liga MX Clausura        CD Cruz Azul    1000000
#
# [2500 rows x 11 columns]
